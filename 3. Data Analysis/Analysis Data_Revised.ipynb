# %% [markdown]
# ### Load Libraries and data head

# %%
import pandas as pd
import numpy as np
from scipy.stats import norm
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
#from sklearn.ensemble import HistGradientBoostingClassifier
from sklearn.impute import SimpleImputer
#from sklearn. ensemble import HistGradientBoostingClassifier

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
# %matplotlib inline

# %%
from sklearn import metrics

# %% [markdown]
# ## Upload the data set

# %%
CFL_lottery = pd.read_csv(r'CFL_lottery.csv')

# %%
CFL_lottery.head()
# Out:
#      Weekday       Date  Pick1  Pick2  Pick3  Pick4  Pick5   CB Winners  \
# 0  Wednesday  8/24/2022    7.0   15.0   33.0   42.0   53.0  4.0       N
# 1    Tuesday  8/23/2022    6.0   20.0   21.0   34.0   49.0  2.0       N
# 2     Monday  8/22/2022    5.0   14.0   48.0   51.0   57.0  1.0       N
# 3     Sunday  8/21/2022    2.0   21.0   30.0   48.0   58.0  1.0       N
# 4   Saturday  8/20/2022   13.0   23.0   37.0   57.0   60.0  1.0       Y
#
#       WinnerLocation      LotteryRetailer                 RetailerCity  \
# 0                NaN                  NaN                          NaN
# 1                NaN                  NaN                          NaN
# 2                NaN                  NaN                          NaN
# 3                NaN                  NaN                          NaN
# 4  HOLIDAY, FL 34691  1552 7-ELEVEN 32852  3437 US HIGHWAY 19, HOLIDAY
#
#          Prize PayoutOption  PrizeAmount QuickPick  WinningTickets  \
# 0          NaN          NaN          NaN       NaN             NaN
# 1          NaN          NaN          NaN       NaN             NaN
# 2          NaN          NaN          NaN       NaN             NaN
# 3          NaN          NaN          NaN       NaN             NaN
# 4  $1,000_WEEK  CASH OPTION    1000000.0         Y             1.0
#
#    Unnamed: 17  Unnamed: 18  Unnamed: 19
# 0          NaN          NaN          NaN
# 1          NaN          NaN          NaN
# 2          NaN          NaN          NaN
# 3          NaN          NaN          NaN
# 4          NaN          NaN          NaN

# %%
CFL_lottery
# Out:
#         Weekday       Date  Pick1  Pick2  Pick3  Pick4  Pick5   CB Winners  \
# 0     Wednesday  8/24/2022    7.0   15.0   33.0   42.0   53.0  4.0       N
# 1       Tuesday  8/23/2022    6.0   20.0   21.0   34.0   49.0  2.0       N
# 2        Monday  8/22/2022    5.0   14.0   48.0   51.0   57.0  1.0       N
# 3        Sunday  8/21/2022    2.0   21.0   30.0   48.0   58.0  1.0       N
# 4      Saturday  8/20/2022   13.0   23.0   37.0   57.0   60.0  1.0       Y
# ...         ...        ...    ...    ...    ...    ...    ...  ...     ...
# 1437        NaN        NaN    NaN    NaN    NaN    NaN    NaN  NaN     NaN
# 1438        NaN        NaN    NaN    NaN    NaN    NaN    NaN  NaN     NaN
# 1439        NaN        NaN    NaN    NaN    NaN    NaN    NaN  NaN     NaN
# 1440        NaN        NaN    NaN    NaN    NaN    NaN    NaN  NaN     NaN
# 1441        NaN        NaN    NaN    NaN    NaN    NaN    NaN  NaN     NaN
#
#          WinnerLocation      LotteryRetailer                 RetailerCity  \
# 0                   NaN                  NaN                          NaN
# 1                   NaN                  NaN                          NaN
# 2                   NaN                  NaN                          NaN
# 3                   NaN                  NaN                          NaN
# 4     HOLIDAY, FL 34691  1552 7-ELEVEN 32852  3437 US HIGHWAY 19, HOLIDAY
# ...                 ...                  ...                          ...
# 1437                NaN                  NaN                          NaN
# 1438                NaN                  NaN                          NaN
# 1439                NaN                  NaN                          NaN
# 1440                NaN                  NaN                          NaN
# 1441                NaN                  NaN                          NaN
#
#             Prize PayoutOption  PrizeAmount QuickPick  WinningTickets  \
# 0             NaN          NaN          NaN       NaN             NaN
# 1             NaN          NaN          NaN       NaN             NaN
# 2             NaN          NaN          NaN       NaN             NaN
# 3             NaN          NaN          NaN       NaN             NaN
# 4     $1,000_WEEK  CASH OPTION    1000000.0         Y             1.0
# ...           ...          ...          ...       ...             ...
# 1437          NaN          NaN          NaN       NaN             NaN
# 1438          NaN          NaN          NaN       NaN             NaN
# 1439          NaN          NaN          NaN       NaN             NaN
# 1440          NaN          NaN          NaN       NaN             NaN
# 1441          NaN          NaN          NaN       NaN             NaN
#
#       Unnamed: 17  Unnamed: 18  Unnamed: 19
# 0             NaN          NaN          NaN
# 1             NaN          NaN          NaN
# 2             NaN          NaN          NaN
# 3             NaN          NaN          NaN
# 4             NaN          NaN          NaN
# ...           ...          ...          ...
# 1437          NaN          NaN          NaN
# 1438          NaN          NaN          NaN
# 1439          NaN          NaN          NaN
# 1440          NaN          NaN          NaN
# 1441          NaN          NaN          NaN
#
# [1442 rows x 20 columns]

# %% [markdown]
# ## Supervised Machine Learning

# %% [markdown]
# ### Data Wrangling

# %%
def recode (day):
    if day == "Monday":
        return 1
    if day == "Tuesday":
        return 2
    if day == "Wednesday":
        return 3
    if day == "Thursday":
        return 4
    if day == "Friday":
        return 5
    if day == "Saturday":
        return 6
    if day == "Sunday":
        return 7
CFL_lottery['Weekdayr'] = CFL_lottery['Weekday'].apply(recode)

# %%
def recode (Wins):
    if Wins == "N":
        return 1
    if Wins == "Y":
        return 2
CFL_lottery['Winnersr'] = CFL_lottery['Winners'].apply(recode)

# %%
CFL_lottery.head()
# Out:
#      Weekday       Date  Pick1  Pick2  Pick3  Pick4  Pick5   CB Winners  \
# 0  Wednesday  8/24/2022    7.0   15.0   33.0   42.0   53.0  4.0       N
# 1    Tuesday  8/23/2022    6.0   20.0   21.0   34.0   49.0  2.0       N
# 2     Monday  8/22/2022    5.0   14.0   48.0   51.0   57.0  1.0       N
# 3     Sunday  8/21/2022    2.0   21.0   30.0   48.0   58.0  1.0       N
# 4   Saturday  8/20/2022   13.0   23.0   37.0   57.0   60.0  1.0       Y
#
#       WinnerLocation  ...        Prize PayoutOption PrizeAmount QuickPick  \
# 0                NaN  ...          NaN          NaN         NaN       NaN
# 1                NaN  ...          NaN          NaN         NaN       NaN
# 2                NaN  ...          NaN          NaN         NaN       NaN
# 3                NaN  ...          NaN          NaN         NaN       NaN
# 4  HOLIDAY, FL 34691  ...  $1,000_WEEK  CASH OPTION   1000000.0         Y
#
#    WinningTickets Unnamed: 17  Unnamed: 18  Unnamed: 19  Weekdayr  Winnersr
# 0             NaN         NaN          NaN          NaN       3.0       1.0
# 1             NaN         NaN          NaN          NaN       2.0       1.0
# 2             NaN         NaN          NaN          NaN       1.0       1.0
# 3             NaN         NaN          NaN          NaN       7.0       1.0
# 4             1.0         NaN          NaN          NaN       6.0       2.0
#
# [5 rows x 22 columns]

# %% [markdown]
# #CFL_lottery = CFL_lottery.dropna()

# %% [markdown]
# ## Picking the x and y variables

# %% [markdown]
# ### X variable

# %%
CFL_lottery = CFL_lottery[['Weekdayr', 'Pick2', 'Pick3','CB', 'Pick4', 'Winnersr','Pick1']].dropna()
x = CFL_lottery[['Weekdayr', 'Pick2', 'Pick3','CB', 'Pick4', 'Winnersr']]

# %% [markdown]
# #x.dropna()

# %% [markdown]
# ### Y variable

# %%
y = CFL_lottery['Pick1']

# %% [markdown]
# #x.info()

# %% [markdown]
# #y.info()

# %% [markdown]
# ### Train Test Split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state=101)

# %%
print(x_train.shape, y_train.shape)
print(x_test.shape, y_test.shape)
# Out:
# (838, 6) (838,)
# (559, 6) (559,)

# %% [markdown]
# ### Create Linear Regression

# %%
lm = LinearRegression()
lm.fit(x_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### Exam Prediction

# %%
predictions = lm.predict(x_test)
predictions
# Out:
# array([20.97298187,  9.7316563 ,  8.93789973,  6.75014618,  3.12584528,
#        16.97170001, 11.36029654, 15.57880548,  6.65279138, 23.68913145,
#        15.97316436,  8.2121375 ,  4.88872626,  7.08594863, 14.06597623,
#        11.44223793, 12.61036324, 12.75837404,  3.11843497,  6.71382517,
#         8.10306988,  8.55075944,  9.42431655, 18.01391747, 15.1502051 ,
#         4.49202184,  1.76018719, 16.97829424,  8.38578414,  3.26012062,
#         6.09208374, 11.02559479,  4.07552285,  1.60907789,  6.80510661,
#        13.05949258,  6.19479834,  5.96280575,  4.97326563, 22.20511326,
#        15.68396911, 16.73020142,  9.71815036,  6.02702149, 14.45965822,
#        11.67518339, 18.28741229, 12.46184198, 10.58575793, 11.12693528,
#        17.59988287,  2.54815199,  4.04674958,  3.51427255,  9.96344356,
#        15.97979576, 12.16638164, 14.13802434,  4.71128565,  7.11370979,
#        12.36804961, 23.75505366, 16.12639032, 19.45763071,  7.50861308,
#         8.90191283, 18.35189969, 20.09800853, 21.87551279, 13.7034744 ,
#         7.80091181,  6.78533559, 10.31412237, 29.10667486,  7.35232514,
#        15.88923013, 18.8308455 , 16.09302238,  7.48515636,  7.55090719,
#         5.52631053,  8.11072093,  6.99141092, 13.24687404, 10.52225798,
#        12.33463676,  4.10393302,  1.0067833 ,  4.66573591, 13.2603763 ,
#        17.86936349, 12.24712206,  3.04129055,  7.23209583,  8.00375443,
#        11.63797759,  4.1821602 , 19.75550892,  5.19729228, 13.77533254,
#         9.94746651,  4.25343179,  5.31329322,  6.31004696,  7.08678328,
#         6.15713911,  9.18797002, 12.0539525 , 20.40752243, 16.48451164,
#        13.76159644, 14.09554523,  1.70801535,  7.04986708, 10.66918169,
#        10.80749478, 11.59786261,  7.25919869, 16.64242868, 16.25561258,
#         9.33180885, 15.91814083, 20.70728721, 11.95276417, 12.71205211,
#        17.45615794,  4.76642739, 19.78884235, 21.87576586,  4.50616814,
#        11.19604265,  5.0378866 , 15.97936634,  7.14952033,  7.02202985,
#         4.8040019 ,  3.05934149,  8.00891385, 12.0700428 , 10.31796022,
#         1.69576787,  7.43716514, 11.84120621, 15.46999894,  5.76706112,
#        19.02124073,  5.92080859,  2.86594241, 11.7297775 ,  3.46351629,
#         3.32762115, 10.23453645,  2.41518332, 11.79781141,  4.80154072,
#         6.67191404, 18.71878268, 14.35644852,  5.38809275,  4.32161611,
#        14.76976732, 11.48569952,  9.91903408,  5.05943152, 11.325497  ,
#         8.80555542,  9.9983477 , 23.35834924, 13.32034334,  8.37563907,
#        14.61111589,  7.93796643,  5.95993115, 10.61120749, 14.04621881,
#        21.63511986,  2.24418736, 13.61484907, 12.79179515, 14.70142846,
#         4.03924637, 10.17370945,  7.07842508, 23.18127494, 25.22179917,
#        10.641553  ,  6.01146392,  7.71397437, 10.28889672,  9.90580347,
#         7.57212664, 10.61781855, 11.04401701,  3.95013909, 17.56182209,
#        13.37309245,  4.27650122,  4.32101595, 11.33600581, 17.45598159,
#        14.75695188, 10.03527816, 16.1630541 ,  5.06981476, 17.47110365,
#         3.90162875,  3.59975227, 16.89294377, 11.85995262,  6.63588501,
#         6.98189564,  2.1067943 , 16.76077581,  6.72834883,  8.5889088 ,
#        13.74977342,  5.89813438,  4.15287381, 10.39873781,  8.36846261,
#        15.59881532, 12.80881972,  5.15817404,  7.08266881, 17.12746884,
#        16.62081265, 15.19067278,  4.5364041 , 13.3488203 ,  6.38470665,
#         7.68745631,  7.57872088,  9.87412277, 20.46764725, 11.58814568,
#        11.08530941, 16.35974662,  4.64713237, 10.63592699, 15.91887521,
#        17.03331778, 15.29091258,  3.42027429,  9.55568766, 21.99581385,
#        24.56635568, 14.50438324, 14.86380514,  8.90674311, 19.00586448,
#        14.40654648,  4.43005634, 19.50749979, 13.91098454,  5.0719846 ,
#         3.17623283,  4.68046812, 21.30559115, 12.11809152,  6.24651243,
#        12.84389092, 15.63549768, 15.45206796, 15.21853532, 13.85438876,
#        20.67219247, 15.14600093,  9.8039964 , 11.39657302,  2.13207681,
#        14.02595655, 11.31925225,  6.44795914,  8.82810076, 10.56219486,
#         6.17556998, 15.18921939,  6.56270162, 12.69665663,  4.34904986,
#         8.42791119,  8.82414902,  6.85771285, 19.24523279, 11.70063792,
#         9.06943358, 18.0302658 , 10.60486568, 20.96579244, 17.44989285,
#         6.45334247,  2.46892742,  5.71855077,  4.62750918,  4.85822795,
#         4.79323137, 14.29599455,  5.81969698, 13.82885815,  4.54617356,
#         2.60660815, 10.24855286,  4.97911555,  4.67954745,  4.67067014,
#         4.05394398, 14.11565534,  7.65350615, 14.71102654,  4.85251224,
#         5.97216934,  5.0838515 , 16.55221575,  4.03448352, 13.87305909,
#        11.55146332, 13.84919714, 12.46322426,  7.37635479,  7.28709839,
#        11.2711843 ,  4.80326255, 12.04287683,  6.89339781,  6.88510769,
#        11.38728551,  4.53386362, 14.61329005,  8.87552899, 16.53955311,
#         5.49783854, 12.93125281,  5.04959141,  7.50015093, 16.7441986 ,
#         2.42358863, 15.12748773,  6.35192591, 11.11102133, 23.48542088,
#         8.40061165,  6.46290661,  7.34968936,  0.82872155])

# %% [markdown]
# ### Graphing Predictions

# %%
plt.scatter(y_test, predictions)

# %% [markdown]
# ### Accuracy Score

# %%
print("Score:", lm.score(x_test, y_test))
# Out:
# Score: 0.3998835742540603

# %% [markdown]
# #### It is low

# %% [markdown]
# ### Mean Absolute Mean

# %%
metrics.mean_absolute_error(y_test, predictions)
# Out:
# 4.65957783798178

# %% [markdown]
# ### Mean Squared Error

# %%
metrics.mean_squared_error(y_test, predictions)
# Out:
# 37.59296788269808

# %% [markdown]
# ### Rooted Mean Squared Error

# %%
np.sqrt(metrics.mean_squared_error(y_test, predictions))
# Out:
# 6.131310453948494
