# %%
pip install sklearn
# Out:
# Requirement already satisfied: sklearn in c:\python3\lib\site-packages (0.0)
# Requirement already satisfied: scikit-learn in c:\python3\lib\site-packages (from sklearn) (1.1.1)
# Requirement already satisfied: scipy>=1.3.2 in c:\python3\lib\site-packages (from scikit-learn->sklearn) (1.8.1)
# Requirement already satisfied: numpy>=1.17.3 in c:\python3\lib\site-packages (from scikit-learn->sklearn) (1.22.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\python3\lib\site-packages (from scikit-learn->sklearn) (3.1.0)
# Requirement already satisfied: joblib>=1.0.0 in c:\python3\lib\site-packages (from scikit-learn->sklearn) (1.1.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: There was an error checking the latest version of pip.

# %% [markdown]
# ### Load Libraries and data head

# %%
import pandas as pd
import numpy as np
from scipy.stats import norm
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.ensemble import HistGradientBoostingClassifier
from sklearn.impute import SimpleImputer
from sklearn. ensemble import HistGradientBoostingClassifier

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
# %matplotlib inline

# %%
from sklearn import metrics

# %%
CFL_lottery = pd.read_csv(r'CFL_lottery.csv')

# %%
CFL_lottery.head()
# Out:
#      Weekday       Date  Pick1  Pick2  Pick3  Pick4  Pick5   CB Winners  \
# 0  Wednesday  8/24/2022    7.0   15.0   33.0   42.0   53.0  4.0       N
# 1    Tuesday  8/23/2022    6.0   20.0   21.0   34.0   49.0  2.0       N
# 2     Monday  8/22/2022    5.0   14.0   48.0   51.0   57.0  1.0       N
# 3     Sunday  8/21/2022    2.0   21.0   30.0   48.0   58.0  1.0       N
# 4   Saturday  8/20/2022   13.0   23.0   37.0   57.0   60.0  1.0       Y
#
#       WinnerLocation      LotteryRetailer                 RetailerCity  \
# 0                NaN                  NaN                          NaN
# 1                NaN                  NaN                          NaN
# 2                NaN                  NaN                          NaN
# 3                NaN                  NaN                          NaN
# 4  HOLIDAY, FL 34691  1552 7-ELEVEN 32852  3437 US HIGHWAY 19, HOLIDAY
#
#          Prize PayoutOption  PrizeAmount QuickPick  WinningTickets  \
# 0          NaN          NaN          NaN       NaN             NaN
# 1          NaN          NaN          NaN       NaN             NaN
# 2          NaN          NaN          NaN       NaN             NaN
# 3          NaN          NaN          NaN       NaN             NaN
# 4  $1,000_WEEK  CASH OPTION    1000000.0         Y             1.0
#
#    Unnamed: 17  Unnamed: 18  Unnamed: 19
# 0          NaN          NaN          NaN
# 1          NaN          NaN          NaN
# 2          NaN          NaN          NaN
# 3          NaN          NaN          NaN
# 4          NaN          NaN          NaN

# %%
CFL_lottery
# Out:
#         Weekday       Date  Pick1  Pick2  Pick3  Pick4  Pick5   CB Winners  \
# 0     Wednesday  8/24/2022    7.0   15.0   33.0   42.0   53.0  4.0       N
# 1       Tuesday  8/23/2022    6.0   20.0   21.0   34.0   49.0  2.0       N
# 2        Monday  8/22/2022    5.0   14.0   48.0   51.0   57.0  1.0       N
# 3        Sunday  8/21/2022    2.0   21.0   30.0   48.0   58.0  1.0       N
# 4      Saturday  8/20/2022   13.0   23.0   37.0   57.0   60.0  1.0       Y
# ...         ...        ...    ...    ...    ...    ...    ...  ...     ...
# 1437        NaN        NaN    NaN    NaN    NaN    NaN    NaN  NaN     NaN
# 1438        NaN        NaN    NaN    NaN    NaN    NaN    NaN  NaN     NaN
# 1439        NaN        NaN    NaN    NaN    NaN    NaN    NaN  NaN     NaN
# 1440        NaN        NaN    NaN    NaN    NaN    NaN    NaN  NaN     NaN
# 1441        NaN        NaN    NaN    NaN    NaN    NaN    NaN  NaN     NaN
#
#          WinnerLocation      LotteryRetailer                 RetailerCity  \
# 0                   NaN                  NaN                          NaN
# 1                   NaN                  NaN                          NaN
# 2                   NaN                  NaN                          NaN
# 3                   NaN                  NaN                          NaN
# 4     HOLIDAY, FL 34691  1552 7-ELEVEN 32852  3437 US HIGHWAY 19, HOLIDAY
# ...                 ...                  ...                          ...
# 1437                NaN                  NaN                          NaN
# 1438                NaN                  NaN                          NaN
# 1439                NaN                  NaN                          NaN
# 1440                NaN                  NaN                          NaN
# 1441                NaN                  NaN                          NaN
#
#             Prize PayoutOption  PrizeAmount QuickPick  WinningTickets  \
# 0             NaN          NaN          NaN       NaN             NaN
# 1             NaN          NaN          NaN       NaN             NaN
# 2             NaN          NaN          NaN       NaN             NaN
# 3             NaN          NaN          NaN       NaN             NaN
# 4     $1,000_WEEK  CASH OPTION    1000000.0         Y             1.0
# ...           ...          ...          ...       ...             ...
# 1437          NaN          NaN          NaN       NaN             NaN
# 1438          NaN          NaN          NaN       NaN             NaN
# 1439          NaN          NaN          NaN       NaN             NaN
# 1440          NaN          NaN          NaN       NaN             NaN
# 1441          NaN          NaN          NaN       NaN             NaN
#
#       Unnamed: 17  Unnamed: 18  Unnamed: 19
# 0             NaN          NaN          NaN
# 1             NaN          NaN          NaN
# 2             NaN          NaN          NaN
# 3             NaN          NaN          NaN
# 4             NaN          NaN          NaN
# ...           ...          ...          ...
# 1437          NaN          NaN          NaN
# 1438          NaN          NaN          NaN
# 1439          NaN          NaN          NaN
# 1440          NaN          NaN          NaN
# 1441          NaN          NaN          NaN
#
# [1442 rows x 20 columns]

# %% [markdown]
# ### Supervised Machine Learning

# %%
## Data Wrangling

# %%
def recode (day):
    if day == "Monday":
        return 1
    if day == "Tuesday":
        return 2
    if day == "Wednesday":
        return 3
    if day == "Thursday":
        return 4
    if day == "Friday":
        return 5
    if day == "Saturday":
        return 6
    if day == "Sunday":
        return 7
CFL_lottery['Weekdayr'] = CFL_lottery['Weekday'].apply(recode)

# %%
def recode (Wins):
    if Wins == "N":
        return 1
    if Wins == "Y":
        return 2
CFL_lottery['Winnersr'] = CFL_lottery['Winners'].apply(recode)

# %%
CFL_lottery.head()
# Out:
#      Weekday       Date  Pick1  Pick2  Pick3  Pick4  Pick5   CB Winners  \
# 0  Wednesday  8/24/2022    7.0   15.0   33.0   42.0   53.0  4.0       N
# 1    Tuesday  8/23/2022    6.0   20.0   21.0   34.0   49.0  2.0       N
# 2     Monday  8/22/2022    5.0   14.0   48.0   51.0   57.0  1.0       N
# 3     Sunday  8/21/2022    2.0   21.0   30.0   48.0   58.0  1.0       N
# 4   Saturday  8/20/2022   13.0   23.0   37.0   57.0   60.0  1.0       Y
#
#       WinnerLocation  ...        Prize PayoutOption PrizeAmount QuickPick  \
# 0                NaN  ...          NaN          NaN         NaN       NaN
# 1                NaN  ...          NaN          NaN         NaN       NaN
# 2                NaN  ...          NaN          NaN         NaN       NaN
# 3                NaN  ...          NaN          NaN         NaN       NaN
# 4  HOLIDAY, FL 34691  ...  $1,000_WEEK  CASH OPTION   1000000.0         Y
#
#    WinningTickets Unnamed: 17  Unnamed: 18  Unnamed: 19  Weekdayr  Winnersr
# 0             NaN         NaN          NaN          NaN       3.0       1.0
# 1             NaN         NaN          NaN          NaN       2.0       1.0
# 2             NaN         NaN          NaN          NaN       1.0       1.0
# 3             NaN         NaN          NaN          NaN       7.0       1.0
# 4             1.0         NaN          NaN          NaN       6.0       2.0
#
# [5 rows x 22 columns]

# %% [markdown]
# #CFL_lottery = CFL_lottery.dropna()

# %%
x = CFL_lottery[['Weekdayr', 'Pick2', 'Pick3','CB', 'Pick4', 'Winnersr', ]]

# %% [markdown]
# #x.dropna()

# %%
y = CFL_lottery['Pick1']

# %% [markdown]
# #x.info()

# %% [markdown]
# #y.info()

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = .4, random_state=101)

# %%
print(x_train.shape, y_train.shape)
print(x_test.shape, y_test.shape)
# Out:
# (865, 6) (865,)
# (577, 6) (577,)

# %%
lm = LinearRegression()
lm.fit(x_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_35360/324431681.py in <module>
#       1 lm = LinearRegression()
# ----> 2 lm.fit(x_train, y_train)
#
# C:\Python3\lib\site-packages\sklearn\linear_model\_base.py in fit(self, X, y, sample_weight)
#     682         accept_sparse = False if self.positive else ["csr", "csc", "coo"]
#     683
# --> 684         X, y = self._validate_data(
#     685             X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     686         )
#
# C:\Python3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     594                 y = check_array(y, input_name="y", **check_y_params)
#     595             else:
# --> 596                 X, y = check_X_y(X, y, **check_params)
#     597             out = X, y
#     598
#
# C:\Python3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1072         )
#    1073
# -> 1074     X = check_array(
#    1075         X,
#    1076         accept_sparse=accept_sparse,
#
# C:\Python3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     897
#     898         if force_all_finite:
# --> 899             _assert_all_finite(
#     900                 array,
#     901                 input_name=input_name,
#
# C:\Python3\lib\site-packages\sklearn\utils\validation.py in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     144                     "#estimators-that-handle-nan-values"
#     145                 )
# --> 146             raise ValueError(msg_err)
#     147
#     148     # for object dtype data, we only check for NaNs (GH-13254)
#
# ValueError: Input X contains NaN.
# LinearRegression does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values

# %%
predictions = lm.predict(x_test)
predictions
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_35360/3692572617.py in <module>
# ----> 1 predictions = lm.predict(x_test)
#       2 predictions
#
# C:\Python3\lib\site-packages\sklearn\linear_model\_base.py in predict(self, X)
#     384             Returns predicted values.
#     385         """
# --> 386         return self._decision_function(X)
#     387
#     388     def _set_intercept(self, X_offset, y_offset, X_scale):
#
# C:\Python3\lib\site-packages\sklearn\linear_model\_base.py in _decision_function(self, X)
#     367         check_is_fitted(self)
#     368
# --> 369         X = self._validate_data(X, accept_sparse=["csr", "csc", "coo"], reset=False)
#     370         return safe_sparse_dot(X, self.coef_.T, dense_output=True) + self.intercept_
#     371
#
# C:\Python3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     575             raise ValueError("Validation should be done on X, y or both.")
#     576         elif not no_val_X and no_val_y:
# --> 577             X = check_array(X, input_name="X", **check_params)
#     578             out = X
#     579         elif no_val_X and not no_val_y:
#
# C:\Python3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     897
#     898         if force_all_finite:
# --> 899             _assert_all_finite(
#     900                 array,
#     901                 input_name=input_name,
#
# C:\Python3\lib\site-packages\sklearn\utils\validation.py in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     144                     "#estimators-that-handle-nan-values"
#     145                 )
# --> 146             raise ValueError(msg_err)
#     147
#     148     # for object dtype data, we only check for NaNs (GH-13254)
#
# ValueError: Input X contains NaN.
# LinearRegression does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values

# %%
plt.scatter(y_test, predictions)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_35360/2570847486.py in <module>
# ----> 1 plt.scatter(y_test, predictions)
#
# NameError: name 'predictions' is not defined

# %%
print("Score:", lm.score(x_test, y_test))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_35360/2576483396.py in <module>
# ----> 1 print("Score:", lm.score(x_test, y_test))
#
# C:\Python3\lib\site-packages\sklearn\base.py in score(self, X, y, sample_weight)
#     718         from .metrics import r2_score
#     719
# --> 720         y_pred = self.predict(X)
#     721         return r2_score(y, y_pred, sample_weight=sample_weight)
#     722
#
# C:\Python3\lib\site-packages\sklearn\linear_model\_base.py in predict(self, X)
#     384             Returns predicted values.
#     385         """
# --> 386         return self._decision_function(X)
#     387
#     388     def _set_intercept(self, X_offset, y_offset, X_scale):
#
# C:\Python3\lib\site-packages\sklearn\linear_model\_base.py in _decision_function(self, X)
#     367         check_is_fitted(self)
#     368
# --> 369         X = self._validate_data(X, accept_sparse=["csr", "csc", "coo"], reset=False)
#     370         return safe_sparse_dot(X, self.coef_.T, dense_output=True) + self.intercept_
#     371
#
# C:\Python3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     575             raise ValueError("Validation should be done on X, y or both.")
#     576         elif not no_val_X and no_val_y:
# --> 577             X = check_array(X, input_name="X", **check_params)
#     578             out = X
#     579         elif no_val_X and not no_val_y:
#
# C:\Python3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     897
#     898         if force_all_finite:
# --> 899             _assert_all_finite(
#     900                 array,
#     901                 input_name=input_name,
#
# C:\Python3\lib\site-packages\sklearn\utils\validation.py in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     144                     "#estimators-that-handle-nan-values"
#     145                 )
# --> 146             raise ValueError(msg_err)
#     147
#     148     # for object dtype data, we only check for NaNs (GH-13254)
#
# ValueError: Input X contains NaN.
# LinearRegression does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values
